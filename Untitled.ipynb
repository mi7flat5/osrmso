# %%
from Router import Router

# %%
router = Router("/home/shane/CLionProjects/ch/data.osrm")
# Out:
# /home/shane/CLionProjects/ch/data.osrm

# %%
data1 = [-80.86,35.21]
data2 = [-78.64,36.78]

router.do_route(data1,data2)
# Out:
# '{"code":"Ok","routes":[{"geometry":{"coordinates":[[-80.86004,35.209976],[-80.809395,35.275931],[-80.776529,35.283496],[-80.766315,35.294293],[-80.695417,35.405415],[-80.655867,35.435998],[-80.596087,35.45182],[-80.562537,35.500475],[-80.573484,35.53853],[-80.551564,35.582561],[-80.463432,35.655055],[-80.410151,35.680592],[-80.387343,35.721872],[-80.338214,35.762657],[-80.188079,35.804642],[-80.127666,35.848112],[-80.012332,35.870602],[-79.905381,35.940022],[-79.883637,35.985268],[-79.804996,36.031954],[-79.769994,36.045959],[-79.685419,36.059595],[-79.484367,36.069269],[-79.398956,36.059763],[-79.371986,36.06862],[-79.282486,36.067819],[-79.225595,36.079176],[-79.160123,36.071989],[-79.146613,36.083182],[-79.101766,36.086582],[-79.096937,36.113322],[-79.056594,36.163222],[-79.017167,36.189859],[-79.045568,36.28437],[-79.023856,36.308996],[-78.987308,36.39417],[-78.975277,36.409055],[-78.899668,36.435106],[-78.824392,36.517471],[-78.789886,36.521286],[-78.775148,36.543545],[-78.7381
# ...

# %%
# %%time
for n in range(0,5000):
    router.do_route(data1,data2)
# Out:
# CPU times: user 1min 15s, sys: 4.03 ms, total: 1min 15s
# Wall time: 1min 15s

# %%
import json

# %%
r = json.loads(router.do_route(data1,data2))

# %%
r['routes']
# Out:
# [{'distance': 293284.8,
#   'duration': 14868.4,
#   'geometry': {'coordinates': [[-80.86004, 35.209976],
#     [-80.809395, 35.275931],
#     [-80.776529, 35.283496],
#     [-80.766315, 35.294293],
#     [-80.695417, 35.405415],
#     [-80.655867, 35.435998],
#     [-80.596087, 35.45182],
#     [-80.562537, 35.500475],
#     [-80.573484, 35.53853],
#     [-80.551564, 35.582561],
#     [-80.463432, 35.655055],
#     [-80.410151, 35.680592],
#     [-80.387343, 35.721872],
#     [-80.338214, 35.762657],
#     [-80.188079, 35.804642],
#     [-80.127666, 35.848112],
#     [-80.012332, 35.870602],
#     [-79.905381, 35.940022],
#     [-79.883637, 35.985268],
#     [-79.804996, 36.031954],
#     [-79.769994, 36.045959],
#     [-79.685419, 36.059595],
#     [-79.484367, 36.069269],
#     [-79.398956, 36.059763],
#     [-79.371986, 36.06862],
#     [-79.282486, 36.067819],
#     [-79.225595, 36.079176],
#     [-79.160123, 36.071989],
#     [-79.146613, 36.083182],
# ...
